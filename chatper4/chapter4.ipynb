# %%
import pandas as pd
import numpy as np
from sklearn import metrics, ensemble,tree,inspection,model_selection
import seaborn as sns
import shap

# %%
import pandas as pd

url = "https://github.com/PacktPublishing/Interpretable-Machine-Learning-with-Python-2E/raw/main/datasets/usedcars-2e.csv.zip"

df = pd.read_csv(
    url,
    compression="zip"
)

df.head()
# Out:
#    price  ...  est_households_medianincome_usd
# 0  33590  ...                          53972.0
# 1  33590  ...                          41994.0
# 2  33590  ...                          44639.0
# 3  33590  ...                          39688.0
# 4  33590  ...                          43267.0
#
# [5 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 256065 entries, 0 to 256064
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   price                            256065 non-null  int64
#  1   id                               256065 non-null  int64
#  2   region                           256065 non-null  str
#  3   region_is_state                  256065 non-null  int64
#  4   region_is_rural                  256065 non-null  int64
#  5   regcenter_dist                   256065 non-null  float64
#  6   posting_date                     256065 non-null  str
#  7   posting_dow                      256065 non-null  int64
#  8   posting_hr                       256065 non-null  float64
#  9   posting_tz                       256065 non-null  int64
#  10  lat                              256065 non-null  float64
#  11  long                             256065 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# price                              0
# id                                 0
# region                             0
# region_is_state                    0
# region_is_rural                    0
# regcenter_dist                     0
# posting_date                       0
# posting_dow                        0
# posting_hr                         0
# posting_tz                         0
# lat                                0
# long                               0
# state                              0
# city                               0
# zip                                0
# make                               0
# make_cat                           0
# make_pop                           0
# model                              0
# model_premier                      0
# year                               0
# make_yr_pop                        0
# model_yr_pop                       0
# odometer                           0
# auto_trans                         0
# ...

# %%
fuel_dummy=pd.get_dummies(df['fuel'],dtype=int)

# %%
df1=df.copy()
full=pd.concat([df1,fuel_dummy],axis=1).drop(['fuel'],axis=1)

# %%
full.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 256065 entries, 0 to 256064
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   price                            256065 non-null  int64
#  1   id                               256065 non-null  int64
#  2   region                           256065 non-null  str
#  3   region_is_state                  256065 non-null  int64
#  4   region_is_rural                  256065 non-null  int64
#  5   regcenter_dist                   256065 non-null  float64
#  6   posting_date                     256065 non-null  str
#  7   posting_dow                      256065 non-null  int64
#  8   posting_hr                       256065 non-null  float64
#  9   posting_tz                       256065 non-null  int64
#  10  lat                              256065 non-null  float64
#  11  long                             256065 non-null  float64
# ...
